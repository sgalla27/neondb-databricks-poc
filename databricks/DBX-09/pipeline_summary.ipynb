# %%
print(f'Bronze: {spark.table("insurance_db.bronze.claims").count()}')
# Out:
# Bronze: 9

# %%
print(f'Silver: {spark.table("insurance_db.silver.claims").count()}')
# Out:
# Silver: 7

# %%
print(f'Gold:   {spark.table("insurance_db.gold.monthly_claim_summary").count()}')
# Out:
# Gold:   3
