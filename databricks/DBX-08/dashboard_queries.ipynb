-- %%
SELECT policy_type, SUM(total_claims) as claims, SUM(total_amount) as amount
   FROM insurance_db.gold.monthly_claim_summary GROUP BY 1 ORDER BY 2 DESC
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>policy_type</th><th>claims</th><th>amount</th></tr></thead><tbody><tr><td>AUTO</td><td>3</td><td>600.0</td></tr><tr><td>HOME</td><td>3</td><td>1800.0</td></tr><tr><td>LIFE</td><td>2</td><td>650.0</td></tr></tbody></table></div>
-- Databricks visualization. Run in Databricks to view.

-- %%
SELECT ROUND(SUM(premium),2) AS total_premiums FROM insurance_db.silver.policies
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_premiums</th></tr></thead><tbody><tr><td>8280.0</td></tr></tbody></table></div>
-- Databricks visualization. Run in Databricks to view.
